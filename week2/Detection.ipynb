# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/hwanghyunjin/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolov8n.pt')
results=model('https://ultralytics.com/images/bus.jpg')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 21.1MB/s 0.3s2s<0.4ss
#
# Downloading https://ultralytics.com/images/bus.jpg to 'bus.jpg': 100% ━━━━━━━━━━━━ 134.2KB 5.0MB/s 0.0s
# image 1/1 /Users/hwanghyunjin/Desktop/CV-Portfolio/week2/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 47.3ms
# Speed: 8.8ms preprocess, 47.3ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 480)

# %%
res=results[0]

plt.figure(figsize=(6,8))
plt.imshow(res.plot()[...,::-1])
plt.axis('off')
plt.show()

# %%
for box in res.boxes:
    conf=float(box.conf)
    cls=model.names[int(box.cls)]
    xyxy=[round(v) for v in box.xyxy[0].tolist()]

    print(f'{cls:10s} conf={conf:.2f} box={xyxy}')
# Out:
# bus        conf=0.87 box=[23, 231, 805, 757]
# person     conf=0.87 box=[49, 399, 245, 903]
# person     conf=0.85 box=[669, 392, 810, 877]
# person     conf=0.83 box=[222, 406, 345, 858]
# person     conf=0.26 box=[0, 551, 63, 873]
# stop sign  conf=0.26 box=[0, 254, 33, 325]

# %%
for box in res.boxes:
    conf=float(box.conf)
    if conf<0.5: continue
    cls=model.names[int(box.cls)]
    xyxy=[round(v) for v in box.xyxy[0].tolist()]

    print(f'{cls:10s} conf={conf:.2f} box={xyxy}')
# Out:
# bus        conf=0.87 box=[23, 231, 805, 757]
# person     conf=0.87 box=[49, 399, 245, 903]
# person     conf=0.85 box=[669, 392, 810, 877]
# person     conf=0.83 box=[222, 406, 345, 858]
